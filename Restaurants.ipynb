# %% [markdown]
# **Restaurant Review Sentiment Analysis using NLP**

# %%
#Import Libraries
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
#Load the data
df = pd.read_csv('TA_restaurants_curated.csv')

# %%
#Keep reviews of restaurants for specific region of Greece (Athens)
df = df.loc[df['City'] == 'Athens']

# %%
restaurant_data = df[['Rating', 'Reviews']]
restaurant_data.head()
# Out:
#       Rating                                            Reviews
# 3434     5.0  [['Excellent experience', 'A nice surprise'], ...
# 3435     5.0  [['One of the best restaurants we ever visite....
# 3436     5.0  [['Great sensorial experience', 'Perfect Way t...
# 3437     5.0  [['Surprise Find!', 'Fabulous evening'], ['01/...
# 3438     5.0  [['A hidden gem in Athens', 'Not just great - ...

# %%
#Number of missing values in the dataset
restaurant_data.isna().sum()
# Out:
# Rating     150
# Reviews    149
# dtype: int64

# %%
# Missing values in Reviews
restaurant_data['Reviews'] = restaurant_data['Reviews'].fillna('["No Review"]', axis=0)

# %%
# Replacing empty Review values
restaurant_data['Reviews'] = restaurant_data['Reviews'].replace(['[[], []]'], 'No Review')

# %%
# Number of missing values in the dataset
restaurant_data.isna().sum()
# Out:
# Rating     150
# Reviews      0
# dtype: int64

# %%
restaurant_data = restaurant_data[restaurant_data["Rating"].notna()]

# %%
# Number of missing values in the dataset
restaurant_data.isna().sum()
# Out:
# Rating     0
# Reviews    0
# dtype: int64

# %%
restaurant_data.Rating.value_counts()
# Out:
#  4.5    661
#  4.0    526
#  5.0    289
#  3.5    204
#  3.0     70
#  2.5     16
#  2.0     15
#  1.0      4
#  1.5      2
# -1.0      1
# Name: Rating, dtype: int64

# %%
#Classifying reviews into “positive” and “negative” so we can use this as training data for our sentiment classification model.
#Positive reviews will be classified as +1, and negative reviews will be classified as 0.

restaurant_data = restaurant_data[restaurant_data['Rating'] != 3]
restaurant_data['Rating'] = restaurant_data['Rating'].apply(lambda rating : +1 if rating > 3 else 0)

# %%
#Keep the usefull information of the reviews
for index, row in restaurant_data.iterrows():
        review = row['Reviews']
        review = review.split("]", maxsplit = 1)
        review = review[0][2:]
        restaurant_data['Reviews'][index] = review

# %%
restaurant_data = restaurant_data.reset_index(drop=True)

# %%
restaurant_data.head()
# Out:
#    Rating                                            Reviews
# 0       1          'Excellent experience', 'A nice surprise'
# 1       1  'One of the best restaurants we ever visite......
# 2       1  'Great sensorial experience', 'Perfect Way to ...
# 3       1               'Surprise Find!', 'Fabulous evening'
# 4       1  'A hidden gem in Athens', 'Not just great - th...

# %% [markdown]
# # Vader knowledge based unsupervised model

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

# Calculate polarity score using Vader
def get_vader_score(sentence): 
    compound = sid.polarity_scores(sentence)['compound']
    if compound > 0.05: 
        return 1
    elif (compound >= -0.05) and (compound <=0.05): 
        return None
    else: 
        return 0
    
restaurant_data['vader'] = restaurant_data.apply(lambda x: get_vader_score(x['Reviews']), axis=1)

# Evaluate results
print(f'Accuracy: {accuracy_score(restaurant_data.dropna()["Rating"].values, restaurant_data.dropna()["vader"].values)}')
# Out:
# Accuracy: 0.9483717235901509

# %% [markdown]
# # Apply TFIDF vectorization to reviews dataset and apply ML algorithms to the vectorized dataset

# %% [markdown]
# ## Cleaning the text data in Reviews

# %%
data = restaurant_data.values    # Gives a numpy array

# %%
# Splitting the reviews and date strings from a single list and considering only the reviews
count = len(data)
all_data = []

for i in range(count):
    rating = data[i, 0]
    reviews = data[i, 1].split('], [')[0]     
    reviews = reviews.replace("[[", "")
    reviews = reviews.replace("'", "")
    reviews = reviews.replace('"', '')
    reviews = reviews.split(',')
    print(reviews)
    for review in reviews:
        all_data.append([review, rating])
# Out:
# ['Excellent experience', ' A nice surprise']
# ['One of the best restaurants we ever visite...', ' A truly delightful evening']
# ['Great sensorial experience', ' Perfect Way to Watch the Sunset in Athens']
# ['Surprise Find!', ' Fabulous evening']
# ['A hidden gem in Athens', ' Not just great - this is awesome food.']
# ['Anniversary Dinner', ' Puerto Rico meets the Brits in Funky Gourm...']
# ['Best Restaurant in Athens', ' New years Eve dinners']
# ['Great Restaurant', ' Outstanding good and service']
# ['The best food experience', ' Cozy & tasy!!']
# ['Dinner with Friends', ' Delicious food']
# ['Traditional Greek food', ' Excellent']
# ['Jewish Sephardi in Athens', ' Kosher restaurant in Athens']
# ['Good value delicious food', ' Excellent New Year’s Eve dinner']
# ['Excellent restaurant', ' Great lunch']
# ['Very good food and atmosphere', ' Top restaurant in good Old Athens']
# ['Outstanding Service', ' Excellent Food and Gr...', ' Fantastic Food and Service']
# ['Best Greek place in Athens', ' Best lamb of my life', ' very fast service', ' k...']
# ['Outstanding place at nighttime', ' Lovely and memorable']
# ['Amazing food', ' Last minute dinner on New Years Eve']
# ['Nicely made', ' Good Indian restaurant near the Acropolis']
# ['Great pleace in a charming location!', ' Highly recommended']
# ['Very special and tasty!!!', ' Sweet New Years Eve dinner']
# ['Nice but pricey', ' Love love love']
# ['Great views', ' food and service', ' Best view to the acropolis']
# ['Food that matches the view - idyllic. An A...', ' Family dinner']
# ['The best ossobuco ever', ' Everything was good']
# ['Authentic Indian Restaurant', ' True indian meal with great service']
# ['Great Greek tapas plates', ' Loved it']
# ['Quick & friendly service + good food', ' Fantastic food']
# ['Modern', ' healthy Mediterranean food!', ' Great healthy Food']
# ['Best experience in Athens', ' One of the best in athens']
# ['Fantastic', ' Yumilicious!!!!']
# ['excellent food and environment', ' Authentic Greek taste!Unforgettable']
# ['Very nice', ' Very nice']
# ['best of- Greek cuisine', ' Tasty', ' affordable food and drink']
# ['simple and authentic home cooking', ' Great place']
# ['Just fantastic', ' Wonderful simplicity']
# ['Great service', ' delicious food', ' So good we came back second night']
# ['Fusion Cuisine From One of Athens top but...', ' Excellent service and interesting food']
# ['Meat platter for 2', ' The best seafood in Athens']
# ['Awesome.', ' Best souvlaki']
# ['Very good lamb', ' Where Food Meets Budget']
# ['Great Deli', ' Mezze and Ouzo', ' Great food', ' decent portions']
# ['beautiful food', ' wine & settings', ' Amazing!']
# ['Cabernet Sauvignon Reserva wine', ' White Wine from Paros']
# ['Nice but small', ' Start your morning here!']
# ['Delicious!', ' The best service and food in Athens']
# ['Really enjoyed our meal here', ' What a pleasure']
# ['Cosy nice restaurant', ' Lovely food and experience']
# ['SUCH a good choice!', ' Overall', ' an amazing culinary experience!']
# ['Liked it much better a second and third ti...', ' Worth every euro.']
# ['Excellent breakfasts', ' excellent New Years...', ' Cant beat the view!']
# ['Excellent in all ways', ' Sunday lunch']
# ['Recommended', ' Yard restaurant / Athens']
# ['Cozy place - delicious food', ' Supertasty']
# ['Amazing Service', ' Amazing People', ' Excellent']
# ['so so good', ' My breakfast pick']
# ['A wonderful family Christmas Eve dinner', ' Delicious and value for your money!']
# ['Good food and large portion!', ' Just gets better and better. Delicious fre...']
# ['Simple tasty food!', ' A very good restaurant in the center of At...']
# ['Lots of food', ' Tasty food-value for money']
# ['Best food in Athens hands down!', ' Great!!']
# ['Amazing local food for a good price', ' well used by local people']
# ['Smoking inside is allowed', ' Beer visit']
# ['Delicious Indian Food', ' Hidden gem for Indian cusinie']
# ['Excellent Restaurant', ' girly outing']
# ['Delicious food', ' A totally fine restaurant']
# ['Spectacular view with excellent food', ' grand food with views to match']
# ['Amazing food and amazing service', ' A wonderful meal with a wonderful view']
# ['Amazing', ' Delicious Traditional Greek Food!']
# ['Athens Beer Restaurnt', ' Reasonably priced', ' good beer and and many...']
# ['Appetisers or Main course?', ' A busy buzzing place']
# ['Fantastic Food Great Prices', ' Ideal for a meal brake from the city tour']
# ['Excellent Lunch With Family', ' Classy but Simple']
# ['Yummy!', ' Traditional Tastes Different']
# ['Family Owned', ' Great greek tomato and cheese salad']
# ['A nice place to eat at the center of Athen...', ' Good place for dinner']
# ['It is okay', ' Recommended!']
# ['To Paradosiako (Evgenia) / Athens', ' Traditional Greek dishes']
# ['A descent water hole', ' Crazily Good']
# ['Mono Restaurant / Athens', ' must visit!']
# ['Excellent', ' Great experience']
# ['Nice place in Exarheia', ' Ecellent choice of typical food and uncomm...']
# ['Fantastic Place!!!', ' Nice seafood experience']
# ['Fancy Roof Top', ' Excellent location!']
# ['great food', ' great interior', ' polite staff', ' The greater food', ' the warmest environment...']
# ['Elegant Dining with an unbelievable view!', ' The food was good enough to match the spec...']
# ['Fantastic!', ' Nice way to enjoy typical food from Crete']
# ['Must visit', ' Total respect for the meat']
# ['Cuisine Grecque revisitée', ' Refreshing and Tasty']
# ['Worth a visit', ' Nice bistro']
# ['Alex the genius', ' Simply excellent']
# ['Good food..friendly staff!!', ' best seafood in athens']
# ['Great Taverna in Athens', ' Reserve in advance and enjoy']
# ['A warm and cozy restaurant', ' Great experience!']
# ['Tasty souvlakis and kebabs!!!', ' Cheap good food']
# ['New Years Lunch', ' One of the best kebab in the town']
# ['Magic moments', ' Authentic Greek place']
# ['Excellent', ' honest food.', ' Best Octopus ever!']
# ['I came for a coffee refill and I liked it', ' Stumbled across this find']
# ['Well...the New Years Eve Buffet menu...d...', ' Nice place to visit']
# ['You feel really welcome there...', ' Feels like(Greece) home']
# ['GREAT view', ' good food', ' Wow What an outlook']
# ['Nice Roman trattoria near the Acropolis', ' Excellent']
# ['Amazing roof top!', ' Great view from the outside terrace']
# ['Ambient bar', ' Nice chill place', ' we enjoyed our late lunc...']
# ['Greek ingredients', ' international style tas...', ' Very good food - excellent service.']
# ['Dinner', ' Fine dining', ' excellent quality']
# ['An authentic Experience', ' Good traditional food in rustic and family...']
# ['Great food', ' Excellent food', ' polite staff', ' central loca...']
# ['excellent views of the Acroplis ', ' made eve...', ' wonderful view']
# ['Deserves the 5*', ' A lot of good food', ' at very decent prices']
# ['Pretty lovely', ' We had a fun night out']
# ['Awesome view', ' Great view of Acropolis']
# ['Great traditional food!', ' No nonsense Greek restaurant']
# ['Loved it!', ' Amazing Greek seafood restaurant']
# ['5 star food', ' Excellent Tapas!']
# ['Great meal', ' One of the best']
# ['Worth a stop but make a reservation for ev...', ' Great Dinner Spot after Visiting the Acrop...']
# ['Air of New York decor mixed with incredibl...', ' Christmas Dinner 2017']
# ['One day trip', ' One Sunday Night']
# ['This place is a gem!', ' Like Eating with Family']
# ['Perfect', ' Favourite Restaurant in Athens']
# ['Magical dinner', ' Perfect in every way.']
# ['Expected more', ' very good but']
# ['Amazing restaurant', ' Oh my']
# ['my favorite', ' Excellent fish and seafood choices']
# ['Excellent traditional Greek souvlaki', ' Wooow']
# ['Holiday', ' Friendly staff and fresh', ' tasty food']
# ['Authentic', ' really tasty (best tzatziki eve...', ' Really good authentic Greek food']
# ['Nice', ' Greek Gourmet']
# ['Nice ambiance', ' Good food', ' Mediocre Service', ' The decor and ambiance is great']
# ['Very good chinese food', ' Excellent Chinese Food in an upscale setti...']
# ['Great seafood', ' Very good']
# ['must go', ' Nice experience']
# ['Best Pita Bar!', ' Delicious quick and cheap']
# ['Excellent but too loud!', ' Great little spot!']
# ['Wonderful NYE Celebration', ' coctails']
# ['Nice food but expensive', ' Best street food']
# ['Great View', ' Dinner or just drinks', ' a great place for e...']
# ['Waouh', ' Great sushi with fresh fish']
# ['People watching - good for food or coffee', ' Lunch at the Agora Athens']
# ['Great place', ' Momazing']
# ['Fantastic sushi', ' Amazing']
# ['Service with a smile :)', ' Nice and good']
# ['Nice atmosphere', ' Great Pub']
# ['DONT MISS IT! Unique!', ' NIGHT OUT']
# ['Great place', ' Oh What a view!!!!!!']
# ['Great location', ' Tasty tasty']
# ['Very nice location', ' Nice evening overlooking the Acropolis!']
# ['Good choice of Greek wines by the glass in...', ' Family Stop At Excellent Wine Bar']
# ['Nice burger place', ' Great food']
# ['Breakfast looking at Acropolis', ' Go for the sunset views']
# ['Yes', ' it is a good place to be', ' Super food on the terrace']
# ['Great Greek Food', ' WE WENT TWICE !']
# ['excellent', ' Very Good -- Nice Outside Seating']
# ['Great food on a cold night', ' Worth the hunt']
# ['First time in Athens- must try', ' Great staff']
# ['England in your glass!', ' Excellent Bar!']
# ['Excellent Szechuan Cuisine', ' Authentic Sichuan in Athens']
# ['Best food in Athens', ' A very decent and smoke free restaurant']
# ['Great Food', ' Gyros']
# ['Lovely place', ' Good food', ' interesting staff']
# ['What an amazing surprise visiting Katsourb...', ' So hospitiable!']
# ['Greek and Mediterranean specialities in th...', ' Great greek food']
# ['Cozy and friendly', ' Perfect for a coffee and a quick bite afte...']
# ['Tasty food But....', ' Excellent homemade Greek cuisine', ' inexpens...']
# ['A classic choice of excellence', ' Wonderful fish dinner - best Ive had in a...']
# ['In the Shadow of the Acropolis', ' Ideal']
# ['Nice Greek grill place', ' Great authentic greek food!']
# ['Cracking good falafel', ' The zen Falafel']
# ['Awesome taste ', ' small plates', ' When you want to return the following day...']
# ['Revithia', ' Time machine authentic Greek taverna']
# ['Excellent value for money!', ' Excellent Dining Experience']
# ['Excellent', ' Best place for dinner']
# ['Excellent assortment of fresh juices', ' Very refreshing!']
# ['Excellent!', ' GORGEOUS']
# ['Cozy place.', ' Good food not where you expect']
# ['Lovely Greek Food!', ' A Lovely Lunch Place in Kolonaki']
# ['Good deserts', ' great views', ' Good', ' but expensive']
# ['Really good Greek inspired food', ' 합리적인 가격의 현대 그리스 요리를 맛볼 수 있는 곳']
# ['A true Greek experience!', ' Amazing']
# ['Saturday Night', ' Superb!']
# ['Never disappoints', ' Good breakfast']
# ['Amazing taste and authentic Greek!', ' Probably more for the meateaters']
# ['Amazing food!', ' Our favorite place for food']
# ['the salt of life', ' Good food', 'a tad expensive']
# ['excellent lunch', ' Amazing food and atmosphere']
# ['Excellent!', ' Excellent beer & food', ' cozy restaurant', ' lo...']
# ['The best place in Athens', ' One of the best taverns in Psirri']
# ['Few steps off the crowd of Thissio an oasi...', ' Exceptional & insider tip!!!']
# ['Great location', ' Excellent service', ' great Pizza', ' coffee and...']
# ['Although we were somewhat persuaded by a v...', ' Pleasant experience']
# ['Best Greek and Mediterranean food in 52 co...', ' Excellent Food']
# ['High level tastes', ' Delicious food', ' friendly staff']
# ['Good Food', ' delicious greek indian mixture food.']
# ['Lovely find', ' Very good Greek food', ' in a boisterous urba...']
# ['Strange restaurant !!!!!!!!!!!!', ' Alternative and good']
# ['Delicious Indian food', ' good indian food']
# ['Great small restaurant', ' Great pasta', ' especially the store-made tag...']
# ['Awesome start to our visit!', ' Friendly staff']
# ['Wonderful!', ' Super delicious']
# ['Great food', ' Good food']
# ['Quiet place', ' good food', ' good service.', ' A nice surprise!']
# ['Great Indian food', ' No gimmicks- just good food']
# ['Just eat your kebap', ' Mmmmmm!']
# ['Romantic all day spot', ' amazing decoration!', ' A secret spot of Paris in Athens']
# ['Great find from Athens', ' Delicous Food']
# ['Great but not excellent', ' A taste of Czecho in the heart of Athens']
# ['Quite place with view on Acropolis', ' Great view and great service']
# ['Food & Cocktails', ' Very nice food']
# ['The friendliest restaurant in Athens', ' Favorite resturant in Athens']
# ['GREAT ATMOSPHERE GREAT DINNER', ' Excellent']
# ['A generally very good experience at a very...', ' Excellent cafe in Athens']
# ['Top quality greek street food', ' Cheap', ' tasty', ' friendly and fast']
# ['Great taverna in a cool area', ' Great local experience']
# ['Great kebab', ' Fantastic value and great food']
# ['only drinks', ' Tasty Greek dishes']
# ['A gem in Athens', ' Delicious local food at great prices']
# ['Asian street food', ' Cheap and tasty!']
# ['Cheap and fantastic', ' Great Place to stop by']
# ['A brilliantly old school restaurant', ' Good Food and Value']
# ['Fresh a la cart', ' Step back in time']
# ['Great place off the beaten path', ' No way you’ll find this on your own']
# ['Coffee', ' light lunch', ' break for shopping', ' Excelllent fresh food']
# ['Out of center', ' but centered on quality foo...', ' When you think you tasted it all']
# ['The Best Falafels', ' The Greatest Falafel in Athens']
# ['Spectacular view and food', ' Great view']
# ['A late find!', ' Lunch stop']
# ['Delicious food and warm atmosphere', ' Rapport qualité prix parfait']
# ['The Real Thing', ' Great souvlaki!']
# ['Awesome!', ' Fantastic']
# ['Very nice and warm place.', ' Great service', ' decent dishes', ' not memorabl...']
# ['Good traditional Greek food', ' Yummy Food', ' Good Price']
# ['A break from all the meat', ' Very tasty', ' friendly staff and cool concep...']
# ['Great Place for Drinks & Finger Food', ' French-style bistro with greek cuisine']
# ['Average sushi and too loud music', ' Good sushi', ' convenient location']
# ['\\\\Quality in central Athens', ' Great breakfast']
# ['Great food & rakomelo at incredible prices', ' Awesome drinks', ' amazing food']
# ['Yum!', ' Crowded but the noodles are superb']
# ['Not to miss for beer lovers', ' Beer Heaven']
# ['Nice Place', ' Coldest drinks']
# ['In the shadow of a bigger beast', ' Great meat-dishes', ' family business']
# ['Stop looking for an Italian!!!', ' Perfetto']
# ['Good choice', ' Fantastic place in Athens!']
# ['Very nice sushi restaurant', ' Great quality']
# ['Just a drink', ' great decoration']
# ['Extreme pleasures', ' Nice place to eat.']
# ['Very good choice for street food', ' Very good choice for ethnic street food']
# ['good local food', ' Great Food', ' Great Music & Great service']
# ['Favorite Local Seafood Restaurant', ' went at noon for lunch - never expected it']
# ['Would go again!', ' Excellent quality', ' tasty food!']
# ['Excellent', ' Friendly', ' Conveniently-Located Hotel']
# ['Tasty food', ' especially the kebab.', ' A nice dinner']
# ['Really enjoyable meal', ' Fantastic food and service']
# ['Great choice of food and drink', ' Great variety and great service']
# ['Great place for lunch!', ' Very Good Traditional Greek Food']
# ['Good food and location :)', ' Good food in the Plaka']
# ['Very nice and local Italian in Athens.', ' Good outdoor seating']
# ['FRESH & PERFECT', ' Juice after race!!!']
# [' Review']
# ['The best Breakfast and Brunch u can get in...', ' Nice place for breakfast']
# ['Piano highnote', ' The best Restaurant in Athens!!']
# ['Great location and food', ' Delicious and amazing value']
# ['Best food in whole Athens', ' Great lunch stop in central location']
# ['Feel like part of the Family', ' Friendly owner']
# ['cant beat the view', ' Very convenient location']
# ['Very good food', ' The best Greek salad we had in Athens']
# ['Good food attentive service fantastic view...', ' We to met George but no regrets']
# ['True farm to table food', ' Very friendly', ' very tasty']
# ['Great little tavern if you near metaxurgio...', ' Finally - greek food at its absolutely be...']
# ['Very good family-run restaurant', ' Home style cooking']
# ['Excellent Menu', ' Chance to encounter with Greek culture.']
# ['Really good food', ' Great Fish place']
# ['Good Place for Lunch!', ' Great for lunch and people watching!']
# ['Fully recommended', ' Best fish restaurant in the area']
# ['Dinner', ' High quality food in a lovely setting']
# ['good souvlaki and more', ' The tasties gyros']
# ['Tranquility in the center of Athens', ' Good food', ' regular place']
# ['Good Food with a view', ' Friendly hotel witha god restaurant']
# ['Tasty food and value for money . . .', ' Great restaurant close to the market']
# ['Youll never get bored', ' Great Place', ' nice food', ' friendly staff']
# ['Amazing vegan food!!', ' Nice cafe']
# ['Excellent pork gyro ....but....', ' Delicious chicken gyro']
# ['Nice authentic food', ' Excellent place']
# ['Best pizza in Athens', ' excellent pizza :)']
# ['Woooooooow', ' Though in tourist ... economic']
# ['Great Food', ' Great Location', ' Amazing People', ' best pizza in town']
# ['Rerfect Acropolis view', ' Amazing place']
# ['Great service and great food!', ' Worth a walk']
# ['The best place for greek tapas', ' Nice place for evening drinks and snacks']
# ['Very good restaurant!', ' Very nice place']
# ['Excellent choice!', ' Simple', ' Asian fare', ' reasonably priced']
# ['Nice ambiance', ' great food', ' and extremely a...', ' Great design']
# ['Comfortable/Authentic', ' Ready prepared but still delicious']
# ['Nice service with great food!', ' Excellent service and delicious food']
# ['Telemachos is the man. Meat-man.', ' Great - if you like meat!']
# ['Nice wine. Meh atmosphere.', ' Nice place for a glass of wine']
# ['real greek food in a homemade atmosphere', ' Authentic and delicious']
# ['Near to Acropolis of Athens', ' One of our favorite restaurants']
# ['Oh my!', ' Amazing French restaurant !']
# ['Nice place with great Acropole view', ' So good we went there again for lunch']
# ['Amazing Selection of Ouzo', ' Wine and Beer', ' Ouzo time!']
# ['Delicious food at such fantastic prices', ' Awesome shish tawook...']
# ['Breakfast', ' Excellent brunch']
# ['Wonderful atmosphere', ' End of term dinner']
# ['Great traditional Greek fish restaurant', ' friendly people', ' lovely food']
# ['Simple', ' tasty', ' local food', ' Can’t beat the service!']
# ['All time classic souvlaki', ' Tasty choice']
# ['Great roasted lamb', ' Gyros!!!']
# ['Best restaurant', ' Great view', ' great food', ' great staff']
# ['Great atmosphere and food.', ' Great food & service']
# ['Excellent fish food', ' Yum !! Greek seafood with a twist']
# ['Tasty pizza in good location', ' Good food and atmosphere']
# ['Motorola Moto X', ' Great place to eat']
# ['Buzzy Spot', ' Enjoyable lunch']
# ['An amazing restaurant! Eat like a local...', ' We struck gold!']
# ['Amazing place!', ' What a burrito !!! Loved it']
# ['Outstanding Wine Bar', ' Go here']
# ['Great cheap greek food', ' Nice little traditional restaurant']
# ['Excellent food', ' service and prices', ' Top']
# ['the best sandwich makers !', ' Tasteful and fresh take away sandwiches an...']
# ['Lunch & Dinner', ' great food']
# ['Bravo chef!', ' Indeed one of the best Sushi in Athens']
# ['Amazing!! Best giros in town!!', ' Great food at a great price']
# ['At the Crossroads', ' lovely spot in Exarcheia']
# ['Railroad ribs. Wow', ' Early delicious lunch']
# ['Vegan perfection!!!', ' Best Crepe of Greece']
# ['Vegetarian Souvlaki', ' Wonderful Souvlaki and Kababs in the Palak...']
# ['Good food', ' huge portions', ' Cute']
# ['Good one', ' Loved it!']
# ['A wonderful experience', ' A great find']
# ['Brilliant', ' Just like having a meal with family']
# ['Easy to walk by', ' but you shouldnt', ' Nice surprise!']
# ['Nice place with reasonable prices', ' Great experience and good value for money!']
# ['Good views bad food/service', ' Restaurant on the top of the hill']
# ['Tasty food with excellent service', ' Really nice place and nice personnel']
# ['Good restaurant', ' GREAT FOOD - GREAT SPOT - GREAT SERVICE']
# ['Satisfaction Guarantee', ' A nice modernist meat place']
# ['Very good', ' Very nice place!']
# ['Salsa venue', ' Great restaurant']
# ['Good option', ' Good for a drink in the heart of Athens']
# ['Great place for a drink', ' very interesting']
# ['Great Authentic place', ' hidden among touris...', ' Nice Discovery']
# ['Amazing ambiance', ' Lovely bar with great atmos[here']
# ['Not to be missed street food', ' Yummy street food']
# ['A play on words that plays on your tongue', ' Really good food!']
# ['Quirky dinner but good experience', ' Fun with Good Food']
# ['Delightful Dinner', ' We had an excellent dinner on their terrac...']
# ['Lovely Lunch', ' Capone and Lucky Luciano']
# ['Great pies!', ' Great place !']
# ['Perfect restaurant they welcomed us very w...', ' Perfect Italian taste in Athens']
# ['Delicious food', ' The best lamb ever']
# ['Excellent Armenian restaurant', ' Very good Armenin grill house']
# ['Real thai food.', ' Real thaifood']
# ['Perfect for Afternoon Tea', ' GB Afternoon Tea']
# ['Good Happy Hour Cocktails', ' Very good!!']
# ['Building perfectly maintained', ' interesting...', ' Christening lunch']
# ['More than just a hotel restaurant!', ' Exceptional staff and wine list']
# ['Top tastes...', ' spontan walk in.']
# ['HoneyMoon Trip', ' Vegetarian Friendly']
# ['Good Seafood', ' Everything you might ask for']
# ['The Place You Go When You’re A Tourist', ' Raki with honey']
# ['Unexpected place', ' We will be going again']
# ['Great ambiance and food!', ' Amazing restaurant']
# ['Great breakfast', ' An extremely plesant pavement taverna']
# ['Great bar restaurant', ' Good food', ' great ambiance...']
# ['very good street food and not only', ' Best souvlaki & gyro spot!']
# ['Great place for all seasons', ' Great for a drink & something to eat']
# ['Very good.', ' Down Town Wrap-it-all-up']
# ['Probably the best Authentic Indian Food in...', ' Deserves a try!']
# ['Very nice place!', ' Best coffee in Athens']
# ['Excellent alternative for quality street f...', ' Fed up with Greek Gyros and Souvlaki...the...']
# ['Wonderful Plak restaurant', ' Gyros and Beer']
# ['Love it', ' One of the best gyros Ive had!']
# ['Unique view and premium food', ' Floodlit Acropolis', 'Ambrosia', 'Scentedd herbs...']
# ['Great typical Greek food!', ' Great small caffe']
# ['Great place for lunch', ' Value for money']
# ['Dinner', ' Very nice place']
# ['Very inexpensive', ' really tasty food!', ' Fantastic Potatoes']
# ['world-class takeout pita souvlaki', ' Excellent food']
# ['Best Pommes', ' Fast & Tasty']
# ['Excellent burger', ' Absolute High Class']
# ['Surprisingly good', ' Very good authentic Chinese Food close to...']
# ['Great little place', ' authentic experience', ' Extraordinary Greek Food']
# ['Excellent', ' A great evening down town Athens']
# ['Nice taverna', ' Feels like home']
# ['Pleasant Surprise', ' Many issues']
# ['a culinary travel through Greece', ' Very friendly staff and cosy place!']
# ['Amazing taste of Greece!', ' Hidden treasure']
# ['Very good choice at the centre of Athens', ' Hidden gem on the second floor']
# ['A good', ' quick', ' reasonably priced meal in t...', ' Great', ' down to earth taverna.']
# ['Good traditional food', ' Dinner']
# ['Exceptional Greek Tapas Food', ' Amazing Risotto']
# ['You won’t regret it!', ' Delicious street food']
# ['Saturday dinner', ' Great service', ' food and friendly']
# ['Beautiful location', ' good food', ' slow servic...', ' Average']
# ['Friendly', ' inexpensive. Great seafood.', ' Good value local grill']
# ['Nice dinner', ' slow service', ' a very good alternative']
# ['Traditional food and Greek music', ' Amazing experience']
# ['Had a great time!', ' Great decor & home made cakes']
# ['Beer taps everywhere', ' Cool beerhouse']
# ['Excellent!', ' Amazing Czech food']
# ['Excellent Greek Food', ' Wonderful respite after sightseeing!']
# ['Dinner in Venice-Greece', ' Dissapointment']
# ['Definitely a fun destination', ' Could be the best if prices were lower']
# ['good food for a great price', ' Just what I was looking for']
# ['Just great :)', ' Beautiful garden dining.']
# ['A nice and friendly restaurant', ' Great place']
# ['A wonderful evening!', ' Surprisingly Refreshing']
# ['A step off the busy street', ' One more good choice in the neighbourhood']
# ['very good Greek cuisine', ' Great food', ' relatively plain setting- a mu...']
# ['Organic style alternative greek cuisine', ' Good selection of Greek specialties', ' with...']
# ['Buffalo boy...!!!', ' Very good']
# ['Mixed Grill for 2', ' Best place to grab lunch (occasional smell...']
# ['Convenient and delicious', ' Boutique Hotel Bar with Good Food']
# ['Awsome local food !', ' Excellent and welcoming']
# ['Lovely for a hot drink and chat', ' dinner party']
# ['Simple restaurant not crowded with tourist...', ' Great seafood!']
# ['Service a little too casual', ' It is a real familly restaurant very quiet']
# ['The whole package for a tourist with a tas...', ' GOOD']
# ['Great bar', ' friendly staff', ' Hidden Gem']
# ['Amazing!! Just hoped they would open a bit...', ' best sandwich in the world']
# ['Not my favorite', ' Good food but watch out!']
# ['Great ambience & drinks!!!', ' Nice place']
# ['Great service', ' very good food and very wel...', ' Great for a quick bate']
# ['Nice food and plenty of it', ' Pretty Decent Indian Food']
# ['A little Greek secret', ' Had to go back!']
# ['Good Greek Food', ' Worth seeking out the authentic taverna']
# ['Great place overall', ' Good food and service', ' decent price']
# ['Overpriced though cosy venue', ' Friendly Service Poor Food Quality']
# ['Very Good Sushi', ' Fresh sashimi', ' very good food.']
# ['Amazing degustation menu', ' Unacceptable smo...', ' Great fusion cuisine', ' smoky atmosphere...']
# ['Value for money', ' Nice burgers.']
# ['Beautiful cafe', ' A place worth visiting!!']
# ['Greek Coffee Stop', ' Excellent plateia to sit and have coffee o...']
# ['Past its prime', ' Nice to be back']
# ['Small premises but very good Pizza!', ' small but full of wonders']
# ['regular visitor to Athens 2 months every y...', ' Just like yiayia used to make!']
# ['Great American Food', ' Great american style food in the heart of...']
# ['Fun vibes!', ' Authentic']
# ['Cute little corner bar in a quiet street', ' Excellent and Chilled place']
# ['Excellent place!!!']
# ['Good food', ' music and atmospaher', ' Touristy but cute taverna with lively wait...']
# ['A happy cheerful restaurant which made an...', ' Coupon Included']
# ['the less touristy place in Plaka', ' Quiet place', ' great food']
# ['A master chef that really impressed.', ' Superb food!']
# ['great place in central charming neighborho...', ' Those are the the kind of restaurants I lo...']
# ['Great and delicious find!', ' Best sandwiches in Athens']
# ['Pleasant night out on Xaritos.', ' Good food and location']
# ['Good spot', ' Love the roof terrace']
# ['Rather good choice', ' Nice cafe/ restaurant in a central locatio...']
# ['A nice fish restaurant in Athens', ' Good Seafood']
# ['Awesome food', ' Great service', ' Amazing dim sums and bao buns!']
# ['Bohemian Serendipity', ' classic bar']
# ['Mexican food', ' Mexican atmosphere', ' Nice Mexican Food']
# ['The best pizza in Athens!', ' Best Pizza in Athens - original Italian!']
# ['Superb !', ' Recommended']
# ['Delicious', ' A home away from home']
# ['Awesome with good value', ' Syntrimmi Thisseio']
# ['nice food great service!', ' friendly staff', ' good food']
# ['Good service', ' bi-lingual menu', ' Best gyros in Athens']
# ['BARREDIER UBER ALLES!', ' Great verity of Greek signature drinks']
# ['Best homemade hot dog', ' Lunch']
# ['Amazing night', ' great place', ' Great ', ' Smart and Relaxing']
# ['lucky find via leaflet guy', ' Lunch after museum']
# ['Whoa...way better than I expected', ' Best kebab in the world']
# ['Hidden Gem', ' Great spot.']
# ['Nice place', ' Nice setting']
# ['Winter Warmer👍🏻', ' Great pita! Great souvlaki!']
# ['A bit up its self and yet very good', ' Very nice dinner']
# ['Athenian restaurant with best view of Temp...', ' Delicious Food and Spectacular Views']
# ['The best fillet steak in Greece', ' Excellent']
# ['Definitely our go-to spot', ' Thumbs up!']
# ['Delicious restaurant with friendly service', ' Nice surprise']
# ['Good desserts and location', ' Cosy and lovely', ' great wellcome food and s...']
# ['Exciting view across the city', ' Elegant dinner']
# ['If I had a sixth star', ' I would put it here...', ' Delicious Value for Money']
# ['Nice place with good Cocktails!!', ' close to acropolis']
# ['Nice place', ' Prices']
# ['Homemade pasta at its best', ' The best Italian food in Athens']
# ['Must try the mushroom gyros!!!!!', ' a mustfo...', ' Good Vegan food']
# ['good Thai kitchen', ' What a nice surprise!']
# ['Charming Italian in heart of Athens', ' Hidden gem', ' worth the wait.']
# ['Sea Urchins serve a culinary purpose', ' Fish point']
# ['Good food but average service', ' Good fresh food. Friendly staff']
# ['Excellent', ' Fantastic Asian food in the heart of Athen...']
# ['moderately adventurous cuisine that should...', ' A delicious lunch on a sunny Sunday ...']
# ['Great value for money', ' Summer Dinner']
# ['Hidden Cretan Gem', ' Returning is just as good as the first tim...']
# ['Great food', ' A-Mazing!']
# ['Fantastic host. Awesome good', ' Very welcoming and tasty for not expensive...']
# ['Great cuisine', ' friendly atmosphere', ' Loved it']
# ['Good place but overrated', ' Outstanding fish Restaurant']
# ['A gem', ' The whole package']
# ['One of the best restaurants in Athens', ' Friendly with good food']
# ['Άψογο!!', ' Real food in Fast-food Pangrati']
# ['Delicious traditional Greek food', ' Home cooked good food']
# ['Found by chance', ' Very nice gourmet greek mezedes']
# ['Nice inexpensive place', ' Value for money']
# ['Good atmosphere', ' music and good coffee!!', ' Cocktail bar with class and knowledge']
# ['Trattoria', ' Dinner']
# ['Branch with my wife', ' Perfect for coffee and brunch']
# ['A Family cuisine and atmosphere.']
# ['traditional eastern treats', ' Excellent!!!']
# ['not one of the best but definitely one of...', ' Perfect']
# ['Grate Food Cheap Price', ' Fast Food Pasta']
# ['Nice place for a drink.', ' Perfect place to stop and watch the world...']
# ['lovely bistro', ' Well above average Kolonaki cafe/restauran...']
# ['Night out', ' Lovely restaurant in the centre of Athens']
# ['traditional greek food', ' GREEK FANTASTIC FOOD']
# ['Amazing view', ' place and food', ' Rooftop bar with excellent Greek tapas']
# ['cozy and tasty', ' Tastefull']
# ['Summer Dinner', ' Very nice place to eat']
# [' Review']
# ['The luxury of the classic taste', ' Πεϊνιρλί']
# ['Old style Greek..', ' ok meat but poor service']
# ['Traditional Greek', ' Delicious Greek Meal... love from Norway']
# ['Press Cafe aka Black Sheep Cafe', ' Very good food']
# ['Excellent Gyros', ' Great Gyros']
# ['Good food', ' good service', ' thus worth a retu...', ' Fantastic Greek lunch']
# ['Friendly restaurant with good Greek food', ' Not what you expect for the location']
# ['Perfect anytime', ' Good Osterman anytime !!']
# ['I eat there and you can eat there too', ' Fokionos greatest']
# ['Lovely cozy pizza place', ' Overpriced!!']
# ['Very friendly staff and high quality cuisi...', ' a very nice Mediteranean style cafe - Rest...']
# ['Noisy place', ' Beer and food']
# ['Delicious Food', 'an authentic Greek Taverna', ' Great Food']
# ['An old stalwart', ' Traditional']
# ['A very good place fro a quick lunch', ' Tasty but extremely expensive for what off...']
# ['Coming back for more!', ' Just ok!']
# ['Good Indian Restuarant', ' Great', ' tasty food']
# ['Excellent', ' Excellent for breakfast.']
# ['verygood rate between quality and price', ' Very good food at very good price']
# ['A place to repeat', ' Dark cellar with delicious food and good w...']
# ['What you pay.... you eat', ' Trust Ntinos- he knows']
# ['Just excellent !', ' Cozy French bistro in the heart of classic...']
# ['A traditional tavern with live music', ' Cozy place-cozy food']
# ['Small gem', ' Great place for breakfast']
# ['Great view', ' CHRISTMAS EVE DINNER', ' SO MUST COME BACK']
# ['ΚΑΘΑΡΑ ΔΕΥΤΕΡΑ Greek Holiday', ' great food!']
# ['Superb Meatballs on Gill with hand made fr...', ' Very good but overpriced']
# ['Pairi rules', ' This THE bar!']
# ['Amazing baked potato food!', ' Rude staff!']
# ['Excellent!!!', ' Mediterranean delight']
# ['Great!', ' great quality and authentic italian kitche...']
# ['Avoid the special meat balls', ' Best in Plaka']
# ['Gyro pita - with a twist', ' Good food', ' in a nice square']
# ['Nice spot in Kolonaki', ' Fantastic place! Excellent food and servic...']
# ['New York in Athens', ' Nice food but overpriced']
# ['Great view of Acropolis', ' Great beer.']
# ['Unique']
# ['Right at the end of our street', ' Lovely restaurant']
# ['Can be romatic', ' Nice view ok prices.']
# ['Nice dinner', ' Great little find']
# ['As expected', ' The best mezedes restaurant Ive found in...']
# ['Amazing', ' A gem']
# ['Reunion', ' Really nice place..']
# ['One of the best Asian restaurants in the...', ' Decent sushi for cheap']
# ['Great pasta', ' Simple and very good food and service']
# ['very good greek food', ' Great food and service']
# ['An old time classic in the business distri...', ' Classy restaurant and bar']
# ['Interesting smoothies!', ' Breakfast and smoothies']
# ['Decent and quite good value', ' An interesting choice']
# ['Excellent food & atmosphere!']
# ['Cute Restaurant', ' Relaxing ans Elevated Culinary Experience']
# ['Dining roulette', ' Authentisch und herzlich']
# ['AMAZING VIEWS AND GREAT FOOD', ' Good food with great view']
# ['Good noodle soup Phở', ' Nice and friendly']
# ['Healthy and delicious', ' Delicious!']
# ['Ok place with cheap food', ' Awsome homemade food']
# ['NICE PLAICE IN PALAIO FALIRO NEAR THE BEAC...', ' Good location . Bad side dishes.']
# ['very good value for money', ' Fantastic patio in the square']
# ['Great atmosphere.', ' Friday night music event']
# ['Best coffee in Athens', ' Excellent coffee and service']
# ['Best Souvlaki in town! Dont miss it!', ' Nice location', ' great food!']
# ['Another reasonable and delicious Greek res...', ' Good Lamb Chops At Fair Price']
# ['Great food', ' warm welcome', ' great prices!', ' Very good Greek family food']
# ['Nice cafe with great breakfast', ' Touch down in Athens']
# ['Worth visiting: friendly service', ' good win...', ' All came to rest in this authentic Greek o...']
# ['Great value for money', ' Very nice restaurant AND cheap!!']
# ['Dinner', ' A Sweet Stop!']
# ['Very good food', ' Value for money.... and great authentic G...']
# ['Αξιολογηση', ' Excellent food and very verygood price']
# ['Excellent food in a very special setting', ' Very nice restaurant for all tastes']
# ['Healthy and tasty', ' Vegan food to die for!']
# ['Wide variety and low prices', ' Nice pub', ' good location']
# ['Best cheesecake in Athens', ' The cutest version of a coffee shop ..']
# ['The best place in Athens to eat']
# ['Cozy taverna', ' Delicious Home Made Food!!!']
# ['Amazing food!', ' An excellent fish restaurant in downtown A...']
# ['The best in Athens', ' Great Greek food', ' great value for money !']
# ['Good place to people watch on Sat morning', ' Superb moussaka']
# ['The place for hot dog!', ' Try the Burger']
# ['Best local meze restaurant', ' A must if you are in Athens']
# [' Review']
# ['Cheap untasteful under cooked meat', ' Great vegetarian burger.']
# ['Amazing!']
# ['Good food', ' great ambience', ' Best Stuffed Wine Leaves in Athens']
# ['A place for Athenians', ' excellent']
# ['Delicious cheesecake', ' So Cute']
# ['the best bao buns ever!', ' still waiting for the food ....']
# [' Review']
# ['Good grilled meats', ' good service', ' nice spo...', ' Average restaurant']
# ['Certainly not sad', ' Sunday lunch close to Acropolis']
# ['Exceptional Greek traditional cuisine', ' A place to visit again. tasty food and ple...']
# ['Absolutely amazing local food', ' Nice choice for lunch in modern friendly a...']
# ['Lovely Pakistani food', ' Authentic', ' great taste and well priced']
# ['Quick lunch stop', ' A nice surprise']
# ['Business dinner', ' Not what it used to be']
# ['Fantastic food and service!', ' Great place!']
# ['Nice and cozy', ' could be vastly improved wi...', ' Paella party']
# ['The new era of the Greek Bar', ' Amazing food!!']
# ['Excellent', ' Paradise for wine lovers']
# ['Unexpected Suprise', ' Amazing']
# ['a hidden little 3-generations taverna', ' Traditional Greek Taverna where the locals...']
# ['One of the best meals in Greece!', ' Great Food & Awesome Service']
# ['Ambience & unique music!', ' One of the most civilized places in Athens...']
# ['good food at good cost!', ' Great food & super cheap']
# ['Evening out', ' It had better days...']
# ['Food and the sea', ' Wow!']
# ['good pizza!', ' Flamme Rouge']
# ['Great food and friendly service', ' Tasty & Friendly']
# ['Perfect profiteroles', ' Pleasant surprise!']
# ['Nice place altogether', ' Could not fault it']
# ['Thankfully places like this still exist!', ' If Greece enforced smoking laws this would...']
# ['Nice chocolate babycakes and bougatsa for...', ' walking down Athinas street']
# ['Best Chinese in Athens', ' good Chinese food served here']
# ['Great place to relax and eat in the center...', ' Nice corner to have brunch and watch peopl...']
# ['No words!', ' Great bar']
# ['What a place........', ' woody allen place']
# ['Great food and ambiance', ' Excellent contemporary restaurant']
# ['A pearl', ' Art group meeting']
# ['Very good Restaurant', ' Exceptional place']
# ['Top quality fast food', ' Tasty and cheap']
# ['Walking distance from Intercontinental hot...', ' Great Service', ' Amazing Food and Super Atmo...']
# ['Authentic', ' tasty and friendly', ' very tasty food']
# ['Good Traditional Food', ' Good traditional Greek food']
# ['Go there for the show not for the food.', ' folk dance &Greek singer& live band&breaki...']
# ['Tourist trap', ' Nice ambience']
# ['It nice but they can make it better', ' About']
# ['Great place in the heart of Athens', ' The famous restaurant']
# ['Get ready to dance', ' Fun club/bar']
# ['Excellent', ' All time classic']
# ['Small place ', ' but great service', ' Amazing hospitality']
# ['Absolutely excellent', ' Delicious authentic Greek fare without a l...']
# ['Jazz Bar', ' GREAT']
# ['An Athens favourite', ' Best wine bar in the area', ' amazing brunch...']
# ['Great food', ' great service', ' great price', ' Excellent']
# ['Fantastic Scottish pub in Athens', ' Lively']
# ['Good quality bar!', ' Wonderful bar']
# ['Brilliant tradional Greek food', ' super all!!!!']
# ['Very nice spot to stop for a meal in the a...', ' Good location - friendly people']
# ['Fine Dining and Excellent View', ' Polisius!']
# ['Super food and drinks', ' Delicious food and beautiful views']
# ['Great food', ' lovely garden', ' Great place for meat lovers. Grilled Lamb...']
# ['Lovely caffe / restaurant', ' Nice unassuming all-day cafe and restauran...']
# ['Good but for the rich!', ' Perfect choice']
# ['Great Subs!!!', ' Better than average but very good too gene...']
# ['Good food in a quiet neighborhood', ' The real greek cuisine and kindness']
# ['Brunch', ' A decent cafe']
# ['Excellent Italian food in the Kolonaki', ' All-time favorite']
# ['Good food', ' very slow service', ' Juicy Burger']
# ['Nice view', ' Excellent drinks with a view']
# ['Great cafe', ' Great quality and service!']
# ['Summer nights']
# ['A lovely restaurant in a musical atmospher...', ' The place to be!']
# ['Great little spot', ' Meatballs']
# ['Typical nice Greek cuisine', ' A local gem']
# ['A posh corner', ' Elegant']
# ['Lovely place for brunch and drinks', ' Expected more..:']
# ['The best pop corn!']
# [' Review']
# ['Decent and inexpensive', ' with fast service', ' Good but not the best']
# ['Very good choice', ' Yummy']
# ['Wonderful garden', ' tasty food', ' simply wow :) traditional greek place - mo...']
# ['Brewski', ' Awesome']
# ['One of our favorite restaurants in Greece', ' Wonderful family tavern']
# [' Review']
# ['I would go again', ' Finger Dipping.....']
# ['Best of the best.', ' Love it']
# ['Greek/Italian', ' Excellent Italian']
# ['Not bad', ' Excellent Pastries']
# ['Lot of fun !', ' A great place to start and finish your day']
# ['valuable', ' Delicious Greek dinner']
# ['Lovely little bar', ' Great little find']
# ['Tasty and healthy', ' Excellent addition to Athens food scene']
# ['Fine place.', ' Very good']
# ['Good choice after drinking', ' After a night out']
# ['Great cocktails', ' Really small bar']
# ['Best polynesian restaurant in town', ' Theme for an imaginary western- Glorious p...']
# ['Great hospitality!', ' Lives up to the hype']
# ['Tasty foods in good prices', ' Good Turkish cuisine']
# ['Very nice place', ' Delicious', ' well served and very well price...']
# ['Great view. Expensive and lack of options', ' Good dinner spectacular view']
# ['Amazing Mouzaka', ' An unexpected find']
# ['It is a bar in full meaning', ' Oldest and best bar in Athens']
# ['Inside the trees', ' Nice ambiance.']
# ['Great food', ' great atmosphere', ' Very special combination of cafe with gour...']
# ['Escape from the Sun', ' Great!']
# ['Hidden Gem', ' A great little local bar!']
# ['Delightful Lunch at Pepes', ' Poor food', ' waitress mainly interested in t...']
# ['Quirky and fun', ' You have to visit once']
# ['Nice place', ' polite people! Excellent food', ' Afternoon Lunch']
# ['Excellent location', ' very friendly waiter', ' Friendly staff']
# ['Nice place', ' nice food', ' A different place!']
# ['Casual lunch and people watching', ' Good gyros!']
# ['Amazing coffee fast service', ' The best cappuccino']
# ['Exciting!', ' Lunch and coffee']
# ['Great Location', ' a big building and nice seating']
# ['Average Lunch', ' A taste of Greece', ' fantastic']
# ['Great Steaks', ' Excellent food!']
# ['A good place for souvilaki in the neighbou...']
# ['Fantastic Greek!', ' YUM! KEBABS!']
# ['Filter Coffee', ' Not bad']
# ['a very good and cozy italian restaurant', ' First meal in Athens']
# ['Authentic friendly delicious', ' Excellent place!! Good food and good servi...']
# ['Lovely food and wine', ' A warm welcome']
# ['Yes Yes Yes', ' !!!!!!!!!']
# ['A new spot in the upcoming Athenian distri...', ' Bringing some new ideas to food']
# ['Εξαιρετικό - Excellent', ' A nice local restaurant']
# ['What a great discovery', ' Great Greek bistro/tapas place.']
# ['Juicy Burger', ' Fantastic excellent delicious']
# [' Review']
# ['Friendly and very helpful. Amazing Greek F...', ' Brilliant staff', ' a real modern Greek cafe']
# ['Best coffee ever...', ' Perfect coffe break']
# ['Great Local Cuisine']
# ['Dark ice-cream', ' Nice sweet and salty food choices...']
# [' Review']
# ['Best Italian food in Kolwnaki!!!', ' Highly recommended!!!']
# [' Review']
# ['Excellent choice', ' Nice diner but could be better']
# ['Amazing gyro pita', ' Nice souvlaki!!!']
# ['Filling', ' budget', 'sport restaurant n outdoor', ' excellent atmoshere / nice food']
# ['BBQ delights', ' Great food at great prices']
# ['Classic is superb', ' A spot of class']
# ['Great environment', ' beautiful garden.', ' Hidden Gem in Athens']
# [' Review']
# ['Wouldnt really recommend this place', ' Unappetizing pseudo-Asian noodle bowls']
# ['Ideal for souvlaki lovers lunch', ' The Best souvlaki in Exrhia area!']
# ['Best street food in Athens by far', ' Every time']
# ['Good food', ' Lunch']
# ['Nice surprise', ' You need to visit!']
# ['Great Place for lunch', ' Could do better']
# ['WOW ... AMAZING']
# ['A piece of art', ' Extremely disappointing']
# ['Very nice view ...']
# ['Nice Place On A Bustling Street', ' Good local cuisine']
# ['Burger at its best!!!', ' This is not an original brisket']
# ['Chill out place with good food', ' Cosy place', ' tasty food', ' too much smoke.']
# ['just good', ' False advertising']
# ['Did not disappoint!', ' Brilliant', ' fun and memorable evening']
# ['Great food: Greek and Pizza', ' Nice outing at La Boheme']
# ['We had a blast here!', ' Cozy']
# ['Best Night Out in Athens!!!', ' The best night ever']
# ['it was better than we expected', ' Lovely place']
# ['Home made food', ' small family restaurant', ' Tastyful greek food in the heart of Athens...']
# ['Live music & BBQ']
# ['nice place to hang out', ' A great meeting point']
# ['Great rooftop', ' Great meat at affortable price']
# ['Coffee under the Acropolis', ' Amazing Homemade Lemonade']
# ['Very nice wine bar in Acropolis area', ' Cozy Paris in a Greek hidden street']
# ['The best place for meze', ' in a cozy atmosph...', ' In decline']
# ['Nice terrace', ' Beautiful terrace', ' nice service/drinks/foo...']
# ['high end Chinese fast food', ' Good sized portions']
# ['By far the best seafood in central Athens', ' Quality fish restaurant']
# ['very nice coffee', ' and always a positive su...', ' Morning coffee']
# ['Nice Place Nice Atmosfere', ' Nice bar with good music!!!']
# ['Nice club restaurant', ' Great place to go out!']
# ['Fantastic food!!!', ' used to be a decent joint for souvlaki by...']
# ['Dreamy cafe!', ' Made with Care!!']
# ['Spectacular view of the Acropolis with Hig...', ' Exceptional cocktails']
# ['Beautiful food at cheap prices', ' The best located bistro in Athens']
# ['Beautiful View.. Must Visit It..', ' Stylish with a tremendous view']
# ['Lunch with friends', ' noon lunch']
# ['I love this place', ' All time classic']
# ['Romantic dinner with virws', ' spectacular view on the acropolis']
# ['Amazing greek food - A hidden gem!', ' The most delicious food downtown!']
# ['Good food ', ' bad service', ' Great fish tavern']
# ['The different Colours of Parthenon', ' Nice quiet rooftop with amazing Acropolis...']
# ['Lovely', ' Lovely']
# ['Great', ' Perfect stop for coffee and a quick meal']
# ['Great place to chill', ' Awesome & friendly']
# ['LOVELY RESTAURANT', ' Very pleasant evening']
# ['Shutdown', ' Really Delicious Food!']
# ['great view', ' Nice food and beer', ' cocktails were ordinar...']
# ['Superbly Sweet', ' Amazing']
# ['A taste of Turkish Cuisine in the center o...']
# ['Very delicious food and friendly stuff', ' Best gyros I had in Greece']
# ['Cozy café in Athens historical neighborho...', ' Art and culture!']
# ['Very good food and friendly welcome', ' Cosy']
# [' Review']
# ['Fcafe', ' Trip']
# ['Charming and delicious', ' nice place']
# ['Gyros', ' Tavern-tsipouro bar']
# ['Excellent service and food in this small s...', ' Peek a 🌹']
# ['Finally exactly what we needed!']
# ['Nice Sandwich shop', ' Mr Newman']
# ['Sunday celebration']
# ['Awesome place', ' The small BEE cafe to Be!']
# ['Very nice place']
# ['Great place great people', ' My experiance']
# ['A Decent Lunch', ' Great for lunch.']
# ['Totally Recommended!', ' a very greek night out indeed']
# ['The show must go on', ' Good music']
# ['Real fresh', ' Delicious pizza!']
# ['For meat Lovers end not only', ' Would have loved to stay the whole day!']
# ['Better service than food', ' Best tzatziki in Athens']
# ['coffee and more', ' Courteous and good']
# ['Not what it used to be', ' Dinner']
# ['Where not to go for coffee in Athens', ' Wonderful place', ' fantastic food']
# ['Comfortable and tasty', ' Midnight snack']
# ['Excellent', ' exi(t) the ordinary']
# ['Simply delicious', ' One of the best old places in the Center']
# ['Best', ' authentic', ' hole in the wall Greek...', ' A real feel for Athens']
# ['Excellent place but smokers spoil it', ' GREAT PLACE IF YOU ARE IN THE AREA']
# ['great ambience and spread', ' Nicely Done']
# ['Plain and real', ' The place to go for pork chops.']
# ['Lunch', ' Wonderful place not the best service']
# ['Jazz night!', ' A very nice place but now closed']
# ['Great place to be']
# ['Noodle bar', ' Food!!!!!!!']
# ['Could have been better', ' Fresh seafood in the northern suburbs']
# ['Sweet Athenian atmosphere', ' the uniqueness...', ' Good choice between Kerameikos Station and...']
# ['Decent food', ' mid-range towards expensive', ' nice place for coffee and a talk']
# ['What! A! Place!', ' Great restaurant']
# ['Very good place! Superb service', ' Cozy place in awkward location and friendl...']
# ['Okay but nothing special', ' Authenthic Greek food']
# [' Review']
# ['Auld Lang Syne', ' As good as ever!']
# ['New dishes make a good place even better.', ' Simple and very good']
# ['Make a point in visiting it']
# ['Typical Greek food', ' excellent service', ' Lunch during Lent days before Easter']
# ['Excellent value for money!', ' excellent spot and street food']
# ['Sushi in Greece', ' It used to be better...']
# ['Traditional Greek cuisine with a twist', ' Highly Recommended Greek Cuisine']
# ['Great location', ' Breakfast Each Morning']
# ['Does not worth it', ' Very nice italian food in athens!']
# ['YUM and great seating', ' Lovelly setting and great food']
# ['Super drinks in a beautiful neighborhood', ' Really cool']
# ['Good value - catching tourists', ' Good Spot Near Ancient Agora']
# ['Good food', ' friendly waitress', ' Authentic Chinese Food']
# ...
# ['Gourmet Souvlaki!']
# ['A small oasis of flavours and tranquillity...']
# [' Review']
# ['Ay Caramba !!!', ' High quality Tequila and Mezcal bar']
# [' Review']
# ['Gourmet souvlaki']
# [' Review']
# ['Rum fashioned lover!', ' Nice atmosphere', ' less than average sushi']
# ['cosy restaurant - Excellent service', ' Quiet', ' comfortable and nice food']
# ['Excellent value for money', ' Best gyros weve had']
# ['Kingdom of mezes']
# [' Review']
# ['greek modern coffeeshop']
# [' Review']
# ['Excellent!!!', ' Good for breakfast']
# ['Very Good food', ' Nice EXPENSIVE Argentinean meat...']
# ['Lunch', ' Very good experience']
# ['The best!']
# [' Review']
# ['Greek gastro meeting', ' Best place ever']
# ['Just The sorriest excuse for dining badly', ' Fish food taverna']
# [' Review']
# ['Cosy place', ' Amazing atmosphere!!']
# ['A Good', ' Informal Place to Eat', ' Solidly Average-']
# [' Review']
# ['Nice place to have a meal', ' Old neighbourhood']
# [' Review']
# ['Nothing exciting', ' The best ever !']
# ['Good and cheap local choice for both meze...', ' Really good meal!']
# ['Best Greek food in town', ' Fallen idol']
# ['small but really huge', ' Too late']
# ['Cosy place for young locals with live musi...', ' Stunning Meze Stop']
# ['Σουβλάκια - Suvlaki']
# ['Looking for a “real” tsipouradiko? You’ve...']
# ['Very nice!', ' Great staff', ' amazing sorbet', ' top notch bat...']
# ['One of the best choises in Athens!']
# ['The best sushi in Athens', ' Simply the best']
# ['Great ice coffee', ' Friendly Server in a Laid Back Environment']
# ['A great choice in Athens !', ' Enjoyable Evening']
# ['Good choice for Greek food at busy Thissei...', ' Restaurant Kabar']
# ['Very nice food and quick service', ' Food and drink']
# ['Afternoon tea', ' Great view of Athens', ' substandard products']
# ['Disappointing', ' Dont know what to think!']
# ['Excellent', ' interesting Thai food and cool...', ' Absolutely superb', ' and great value for mon...']
# ['cosy']
# ['Pleasant way of Shopping!', ' Shopping']
# ['Amazing Bistro in the heart of Athens!']
# [' Review']
# ['Needed a Place to Chill', ' The iconic Greek Gyros']
# ['Nice place', ' Cool place!']
# ['Quick Lunch']
# ['Voodoo-ing', ' Good bar but']
# ['A very good experience overall', ' Cocktails done right']
# ['Five- dish menu', ' tremendous value']
# ['A bit expensive', ' go next door to Ydria in...', ' Good location', ' ok food']
# ['Solid Souvlaki and Gyros']
# ['Vasilopita', ' Best quality desserts']
# ['The Pasta Shock!', ' Great lunch']
# ['Best burger I tried in Athens!', ' Amazing burgers']
# ['Great traditional greek food', ' Great food']
# ['Sometimes simple is the best', ' Taste of greek mezes']
# ['Ok food', ' super overpriced for eating on th...', ' Interesting!!']
# [' Review']
# ['Fantastic Food!!', ' vulgar and noisy']
# ['Good food and good ambience', ' Calm and Classy']
# ['Interesting and lovely place', ' Innovative - chic - tasty']
# ['Great Garden']
# ['Very good quality', ' too expensive', ' Lots of flavours not enough taste']
# ['Good food but limited menu & no credit car...', ' My second visit']
# ['Good and fair choice', ' meat lovers paradise']
# ['A bit underwhelmed', ' Not impressed with the food']
# ['Clean & comfortable', ' The best greek salad ever']
# ['Nice atmosphere', 'nice food']
# ['Great intro into greek pastries n coffee', ' Take away Greek food']
# ['Come in a warm evening', ' Old time classic Kafeneion - Greek Alkohoo...']
# ['A London themed cafe-bar opposite Athens b...']
# ['nice place', ' Clubbing in Chic Kolonaki !!']
# ['Great food!', ' Wish this place was local in my neighborho...']
# ['Lovely food and atmosphere']
# ['Best souvlaki in northern Attiki', ' The best souvlaki in Athens!!!']
# ['Excellent']
# ['Amazing dinner', ' Fatty food :(']
# ['Good food', ' view and atmosphere', ' Very disapointing']
# ['Great place for morning coffee', ' Pleasantly surprised. Great Place']
# [' Review']
# ['Fantastic night out']
# ['Classic tavernaki in Kifissia']
# ['Excellent place to go out with friends']
# ['The best souvlaki in Athens', ' One of the best in the city']
# ['Cafe with basic Greek food near to cathedr...', ' NICE PLACE']
# ['Athen']
# ['Good place for a break', ' A good place for a relaxing coffee/juice b...']
# ['Good views', ' good views', ' good service', ' Great view to Acropolis']
# ['Nice place', ' good thin crust pizza', ' Poor service and menu']
# ['Rude and Aggressive.', ' Rad place', ' rad owner']
# ['Acropolis view was wonderful', ' Great views']
# ['Great food and staff!', ' Great food']
# ['Worth coming!', ' Eat like the locals with affordable prices']
# ['Mandatory stop for bougatsa and coffee', ' You can find much better bakeries']
# ['Nice Club for uber locals', ' Great for people watching but average food']
# ['Good for after office drinks!']
# [' Review']
# ['Very good service', ' great food', ' frozen food at the price of a 5 star hote...']
# ['Value for money gourmet cuisine', ' A Greek pub with a twist!']
# ['a perfect night out']
# ['delicious food', ' Comfortable and quiet']
# ['Dinner for 2 at Mezedomachies.', ' Excellent Greek home cooking', ' a little off...']
# ['High class food with a view', ' Mont Parmes Casino / Athens']
# ['Fun and drinks']
# ['Already in the system as Bouloukos']
# ['A well decorated cafe for every hour', ' food...']
# ['Cozy little place']
# [' Review']
# ['Ups and Downs of Peinologio by Byron.']
# ['Trés chic']
# [' Review']
# ['fish food in affordable prices']
# ['Convenient', ' small', ' stylish', ' sleek', ' reverbe...']
# ['Good Souvlaki Place']
# [' Review']
# ['Ups and Downs of Oinovasilemata']
# [' Review']
# ['Cozy place', ' good food', ' nice prices', ' A gem of a find']
# ['Cielo / Athens']
# [' Review']
# [' Review']
# ['Quite italian taste']
# [' Review']
# ['Grandmas meatballs and more!']
# [' Review']
# ['Nice cafe-bar', ' 4 points for genuinity']
# [' Review']
# ['Amazing Freddo!']
# [' Review']
# ['Albanian Flavour in Greece !']
# [' Review']
# [' Review']
# [' Review']
# ['Good indian restaurant', ' Geraniou', ' the cluster of Curry Cafes']
# [' Review']
# [' Review']
# [' Review']
# [' Review']
# [' Review']
# [' Review']
# [' Review']
# ['Very tasty food.']
# ['in a beautiful neoclassical building']
# [' Review']
# [' Review']
# [' Review']
# [' Review']
# [' Review']
# [' Review']
# ['Souvlaki kalamaki']
# [' Review']
# [' Review']
# [' Review']
# ['The spot is closed', ' The definition of fun restaurant']
# ['Great old warehouse with impressive wine c...', ' Nice food', ' excellent service. Try roof gar...']
# ['Devotion to Service & Quality']
# ['The Real Athens']
# [' Review']
# ['Warm People', ' Delicious Food']
# ['Ups and Downs of Burgers N Roses']
# ['Nice restaurant', ' traditional italian tastes']
# ['Small', ' local restaurant']
# [' Review']
# ['A wonderful corner to taste ouzo and Greek...']
# [' Review']
# ['Chilled out place', ' Great beer selection and tasty food to go...']
# ['Dining with a view of illuminated Acropoli...', ' On top of Stanley Hotel.']
# ['Nice pizza', ' Great jumbo size pizza']
# ['Tasty food', ' but noisy and smokey']
# [' Review']
# ['Drinks', ' Evening drinks and food']
# [' Review']
# ['Cozy but smoky']
# ['a cosy and friendly place']
# ['Victoria kebab', ' Lots of variety!']
# [' Review']
# ['Suggested place for a quick drink', ' No proper decaf coffee']
# ['Good neighbourhood Japanese', ' but not a de...', ' Easy', ' sympatico Japanese']
# ['Fantastic view!', ' Excellent panoramic view', ' average service...']
# ['Very pricey', ' Far below expectations']
# ['Hidden paradise for food lovers!', ' Nothing less than fantastic!']
# ['Nothing spectacular', ' Time and time again']
# ['The sophisticated house of Kebab', ' Shocked']
# ['Great variety of food and dessert in decen...']
# ['Very nice indian food at good price!', ' Nice indian food']
# ['Stale bread', ' Nice ambiance']
# ['exellent food !', ' No baklava :(']
# ['YUM', ' good location', ' good service']
# ['What an evening!', ' For youngsters']
# ['Not bad', ' Nice Kalamaki']
# ['Much needed in Glyfada']
# ['All time Athens Classic Bar', ' All Time Classic']
# ['AB_COMMENTS...']
# ['Nice place', ' Good', ' cheap food', ' but did both end up sick']
# ['Smoking restaurant.']
# ['Gem between all those Greek', ' Excellent Choice!']
# ['a place for mezedes']
# ['Interesting Cuisine', ' Nice Cocktails!', ' Best houmous & pitta bread in athens']
# ['Authentic Sushi Bar', ' Fine sushi']
# ['All time classic', ' Good home made food.']
# ['Nice small restaurant', ' Good Food reasonable prices']
# ['The best gyros/ kebab house in the area']
# [' Review']
# ['Good Greek Food', ' Beautiful Food in great location']
# [' Review']
# ['Good location', ' nice food', ' Excellent Italian - overpriced - food']
# [' Review']
# ['Very nice evening', ' Lovely breakfast and great service']
# [' Review']
# ['Good for Lunch', ' Nice place near the acropolice']
# ['small & cute', ' Real Artist\\s tavern in the Greek Montmar...']
# ['Aggressive Waiters.', ' Really enjoyed this!']
# [' Review']
# ['Average family-run greek traditional resta...', ' Traditional with a smooth modern way by hi...']
# ['OK food', ' but ...', ' very good food', ' very small portions-very o...']
# ['Great find with traditional Greek food', ' Charming!!']
# ['Eat Souvlaki', ' It was good for what it is. Very good ser...']
# ['Arty tavern', ' Smoking everywhere', ' not good']
# ['3 chef tastings', ' French Cuisine in Athens NOT MY THING']
# [' Review']
# ['Nice food and great view', ' Panoramic Views']
# ['Very tasty but expensive food', ' Excellent outdoor (covered) classy restaur...']
# ['Largest market in the city', ' Its a market!']
# ['Best value for money', ' Fast service and good food']
# ['Needs improvement', ' Sun drenched lunch in cool square']
# ['OK food', ' Decent Chinese food']
# ['lovely', ' Very bad']
# [' Review']
# ['Great for meze with friends']
# [' Review']
# ['Quick', ' inexpensive stop for pizza & drinks', ' Tasty pizza']
# ['the best pizza shop in athens']
# ['Fast food sushi', ' Lilliput take away', ' decent', ' overpriced']
# [' Review']
# [' Review']
# [' Review']
# ['Always a pleasure to visit', ' Class reunion dinner at koutouki style tav...']
# ['Great place']
# ['real mexican food!', ' Tasty food with a little too high prices..']
# ['Bad food', ' Original Indian at the worst neighborhood.']
# ['Good atmosphere', ' fast service', ' good food', ' To Elaikon sto Goudi']
# ['no longer exists', ' Letting people smoke inside']
# ['A fabulous garden with not so fabulous foo...', ' Not meeting expectations.']
# [' Review']
# ['The best Suflaki in the world...add tzazik...']
# ['Overcharged - quality below average', ' Great neighborhood place']
# ['Slightly better than a street canteen', ' Fantastic local gem with authentic greek f...']
# ['Average!', ' Brutality!']
# ['Good (if youre less than 25 yrs old).']
# ['Excellent service and great food', ' Great food with excellent service']
# ['Most amazing omelette ever', ' Beautiful morning']
# ['a new take on deliciousness!!', ' An excellent experience']
# ['You did good matilde!', ' Authentic Italian and Not just for pizza']
# ['Great', ' Nice surprise']
# ['rest at noon with acropolis view', ' Could be better']
# ['very nice evening']
# ['Delicious!']
# ['Good choise but a little bit pricey.', ' Avoid it for a drink']
# ['Beautiful breakfast buffet', ' Nice lunch at the Divani Caravel']
# ['Delicious food at a reasonable price!', ' Off beaten path']
# ['Best Greec Music']
# ['Fun with Friends', ' Beer Academy']
# ['Fine Cretan cuisine', ' A taste of Crete']
# ['Simple and clean..!! Good views.', ' Food history in the making']
# ['Very good and cozy', ' Gem']
# ['A nice vivid place to spend an evening']
# ['Very nice', ' cosy bar', ' Amazing']
# ['Totally worth it!', ' Huge Servings of Food']
# ['Fantastic Service and great food']
# [' Review']
# ['Better Than It Looks', ' A great place for late-night snack']
# ['All I want for Christmas.. is food xD', ' Best pizza']
# ['Excellent dinner and cocktails', ' extremely disappointed']
# ['Amazing place to chill-out']
# ['Expensive']
# ['one of the best italian restaurant in athe...', ' A HUGE DISAPPOINTMENT']
# ['Cheap and moderate', ' Great value']
# ['Nice and friendly', ' Very disappointing coffee served']
# ['Nice coffee but uninterested staff', ' Pit stop']
# ['Good food and good value in the heart of K...', ' Good food', ' great service.']
# ['What an experience!!!', ' Very good !']
# [' Review']
# [' Review']
# [' Review']
# [' Review']
# ['Top notch falafel sandwiches for just €2.5...']
# ['Budget dining']
# ['Great Italian style Coffee shop but noisy...', ' Very nice']
# ['No. Thanks.']
# ['Coffee surrounded by superheroes', ' Took ages!']
# [' Review']
# ['Worst cafe experience ever', ' GREAT NIGHTCLUB']
# ['A hidden treasure', ' No mayo', ' no mustard']
# ['Nice Greek tavern', ' If you want to feel young !']
# [' Review']
# ['Απαραδεκτο', ' Dont accept credit cards']
# ['A hidden gem', ' Quick lunch']
# ['Fine quiet verdant arboreal setting pictu...', ' Shame for the Greek Hospitality']
# ['Quaint hole in the wall', ' Grab a bite or a drink during lunch break']
# ['Lunch After Walking Tour In Athens']
# ['Hotel restaurant', ' This is a hotel restaurant']
# ['Very delicious Greek souvlaki', ' Avoid ....']
# ['Perfect!', ' Good food good price']
# ['Now a bar', ' called White Monkey', ' having great time for sure']
# ['Simple', ' brilliant food with great customer...', ' Good home-made style food']
# ['Paula gut und billig!', ' Cheap and cheerful']
# ['Bad quality', ' Fantastic service', ' tasty crepes !!!']
# ['The best pizza in town']
# [' Review']
# ['Very Ordinary', ' Great place for soaking in Greek music and...']
# [' Review']
# [' Review']
# ['Tasteful', ' but a bit overpriced!']
# ['Interesting cuisine', ' great service - simpl...', ' Very nice restaurant!']
# ['Decent burgers', ' Excellent selection - great burgers - grea...']
# ['A Rip off', ' Great place and Hot Dog']
# ['Appreciation']
# [' Review']
# ['Loved it', ' The best food in the hood!']
# ['Lovely food with very friendly service', ' Near the acropolis and a lovely place']
# ['authentic experience', ' A shop for nice people']
# ['Coffee and sandwich while working on my la...', ' Cost place']
# ['good location but noising', ' Disappointing']
# ['A fun night!', ' Good food', ' Live Greek music', ' Lively happy...']
# ['Very bad service and impolite staff', ' A good place to have a night cap']
# ['They don\\t do take out/to go', ' Simple is best']
# ['A gem in the middle of Psyrri', ' Its less than okay']
# ['Excellent food', ' Dinner']
# ['Will come back', ' Nice coffee']
# [' Review']
# [' Review']
# ['Decent and honest place']
# [' Review']
# [' Review']
# [' Review']
# ['Nice place to relax or locals', ' Great meeting point']
# ['EXCELLENT!!!', ' Great food!']
# ['Pesto Trattoria Cafe', ' No pizzas', ' no burgers...']
# ['Excellent all round', ' Great food for low price']
# ['Meat Me / Athens', ' Perfect Greek Salad']
# [' Review']
# [' Review']
# ['Average', ' A bit more than average']
# [' Review']
# ['Very nice', ' Still a favourite!!!']
# ['For coffee', ' Best vibe ever!!']
# ['Value for money', ' Nice environment', ' food just average']
# ['Only if starving', ' In transit']
# ['Friendly neighbourhood restaurant']
# ['Very Tasty Indian Food - nice change from...', ' Average']
# ['Order-in thumbs down']
# ['Catcher in the rye', ' Great and cheap sushi']
# ['Quick lunch', ' We enjoyed the Retsina']
# ['Rooftop dinner in Plaza', ' Worst restaurant in the world - avoid']
# [' Review']
# ['worst shushi ever', ' Bad bad bad sushi']
# ['Worst burger ever.', ' Amazing fast food']
# [' Review']
# ['Closed down', ' Brand new love in town!']
# ['Second time not too good', ' Dinner with rooftop']
# ['Very special place', ' ethnic atmosphere', ' Unique', ' cosmopolitan', ' ethnic']
# ['OK only if they happen to have a music eve...']
# ['Ive had better']
# ['racist dress control & liars']
# [' Review']
# ['One word - Disappointing']
# [' Review']
# ['Just enjoy the view', ' dont try to eat !', ' fantastic setting', ' bad service', ' mediocre t...']
# [' Review']
# ['Worst service ever', ' Terrible all around!']
# ['Indian']
# ['Good for fun', ' bad for food']
# [' Review']
# ['Adrionos', ' Adrianos / Athens']
# ['So bad customer service!!!', ' Excellent Choice']
# ['Dr.']
# [' Review']
# ['Eccellent place!']
# ['last night..']
# ['Interesting']
# ['Dont go there', ' Poor service']
# ['a disappointment']
# [' Review']
# ['microwaved frozen food .']
# [' Review']
# [' Review']
# [' Review']
# [' Review']
# ['Best budget mezopoleio in Psyrri (and pr...']
# [' Review']

# %%
data = pd.DataFrame(all_data, columns = ['Review', 'Rating'])
data.head()
# Out:
#                                           Review  Rating
# 0                           Excellent experience       1
# 1                                A nice surprise       1
# 2  One of the best restaurants we ever visite...       1
# 3                     A truly delightful evening       1
# 4                     Great sensorial experience       1

# %%
# Removing the puntuation marks
data['Review'] = data['Review'].str.replace('[^\w\s]','')
data.head()
# Out:
#                                        Review  Rating
# 0                        Excellent experience       1
# 1                             A nice surprise       1
# 2  One of the best restaurants we ever visite       1
# 3                  A truly delightful evening       1
# 4                  Great sensorial experience       1

# %%
#Remove stopwords

from nltk.corpus import stopwords

english_stop_words = stopwords.words('english')
def remove_stop_words(corpus):
    removed_stop_words = []
    for review in corpus:
        removed_stop_words.append(
            ' '.join([word for word in review.split()
                      if word not in english_stop_words])
        )
    return removed_stop_words

data['Review'] = remove_stop_words(data['Review'])

data.head()
# Out:
#                              Review  Rating
# 0              Excellent experience       1
# 1                   A nice surprise       1
# 2  One best restaurants ever visite       1
# 3        A truly delightful evening       1
# 4        Great sensorial experience       1

# %%
#Normalization to its true root

import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.stem import PorterStemmer
porter=PorterStemmer()
from nltk.stem.wordnet import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

from nltk.corpus import wordnet
    
    
from nltk.tag.perceptron import PerceptronTagger
tagger = PerceptronTagger()

def stemSentence(sentence):
    stem_sentence=[]
    
    for word, tag in tagger.tag(word_tokenize(sentence)):
        wntag = tag[0].lower()
        wntag = wntag if wntag in ['a', 'r', 'n', 'v'] else 'n'
        word=lemmatizer.lemmatize(word,wntag)
        stem_sentence.append(porter.stem(word))
        
    return " ".join(stem_sentence)


for index,row in data.iterrows():
    review = stemSentence(row['Review'])
    data.loc[index,'Review'] = review
    
data.head()
# Out:
#                         Review  Rating
# 0                 excel experi       1
# 1               A nice surpris       1
# 2  one best restaur ever visit       1
# 3         A truli delight even       1
# 4         great sensori experi       1

# %% [markdown]
# ## Split the dataframe

# %%
# Splitting train/test data
x = data['Review']
Y = data['Rating']

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, Y_train, Y_test = train_test_split(x, Y, train_size = 0.7, random_state = 500, stratify = Y)

# %% [markdown]
# ## Vectorization tf-idf 3-grams

# %% [markdown]
# TF-IDF is an abbreviation for Term Frequency Inverse Document Frequency. This is very common algorithm to transform text into a meaningful representation of numbers which is used to fit machine algorithm for prediction.
#
# Count Vectorizer give number of frequency with respect to index of vocabulary where as tf-idf consider overall documents of weight of words.
#
# ![](img1.png)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(ngram_range=(1,3))

vectorizer.fit(xtrain)
vectorizer.fit(xtest)
X_train = vectorizer.transform(xtrain)
X_test = vectorizer.transform(xtest)

# %% [markdown]
# Resampling involves creating a new transformed version of the training dataset in which the selected examples have a different class distribution. Random oversampling involves randomly selecting examples from the minority class, with replacement, and adding them to the training dataset. Random undersampling involves randomly selecting examples from the majority class and deleting them from the training dataset.

# %%
# Check imbalanced data - summarize the class distribution
from collections import Counter

counter = Counter(Y_train)
print(counter)
# Out:
# Counter({1: 2310, 0: 44})

# %%
from imblearn.over_sampling import RandomOverSampler

rus = RandomOverSampler(random_state=777)

X_train, Y_train = rus.fit_resample(X_train, Y_train)

# %%
# summarize the new class distribution
counter = Counter(Y_train)
print(counter)
# Out:
# Counter({1: 2310, 0: 2310})

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# ### Logistic Regression
# Logistic regression is a process of modeling the probability of a discrete outcome given an input variable. The most common logistic regression models a binary outcome; something that can take two values such as true/false, yes/no, and so on. Logistic regression is a useful analysis method for classification problems, where you are trying to determine if a new sample fits best into a category.
#
# The best way to think about logistic regression is that it is a linear regression but for classification problems. Logistic regression essentially uses a logistic function defined below to model a binary output variable (Tolles & Meurer, 2016). The primary difference between linear regression and logistic regression is that logistic regression's range is bounded between 0 and 1. In addition, as opposed to linear regression, logistic regression does not require a linear relationship between inputs and output variables.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

lr = LogisticRegression()
lr.fit(X_train,Y_train)
y_pred = lr.predict(X_test)
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.06      0.26      0.10        19
#            1       0.98      0.92      0.95       990
#
#     accuracy                           0.91      1009
#    macro avg       0.52      0.59      0.53      1009
# weighted avg       0.97      0.91      0.94      1009

# %% [markdown]
# ### K-Nearest Neighbor
#
# K-Nearest Neighbor is an exemplar-based or instance based approach which is effectively applied for sense tagged words. This classification approach based on
# instances where instances are used as points in the vector and test instance compares the new instance with all previously stored instances in the memory.
# It is based on supervised learning algorithm which is provided with the training set and during classification it compares the test instance with training set.
#
# In KNN the classification of new examples are represented in the vector form of ‘n’ features .The exemplar- based methods do not ignore any exceptions so that
# the context should be disambiguated properly.
#
# The K-Nearest Neighbor classifier selects the correct answer by comparing target word with sense inventory dictionary.
# This classifier finds the ‘k’ nearest sample to the target word and the closest sense is selected as the correct sense of the word.

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, Y_train)
y_pred = knn.predict(X_test)
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.18      0.11      0.13        19
#            1       0.98      0.99      0.99       990
#
#     accuracy                           0.97      1009
#    macro avg       0.58      0.55      0.56      1009
# weighted avg       0.97      0.97      0.97      1009

# %% [markdown]
# ### Random Forest Classifier
#
# The random forest algorithm is made up of a collection of decision trees, and each tree in the ensemble is comprised of a data sample drawn from a training set with replacement, called the bootstrap sample.Depending on the type of problem, the determination of the prediction will vary. For a regression task, the individual decision trees will be averaged, and for a classification task, a majority vote,this step is known as aggregation.

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(max_depth=2, random_state=0)
rf.fit(X_train.toarray(),Y_train)
y_pred = rf.predict(X_test.toarray())
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.05      0.21      0.09        19
#            1       0.98      0.93      0.96       990
#
#     accuracy                           0.91      1009
#    macro avg       0.52      0.57      0.52      1009
# weighted avg       0.97      0.91      0.94      1009

# %% [markdown]
# ### Naive Bayes
#
# Naive Bayes is a family of probabilistic algorithms that take advantage of probability theory and Bayes’ Theorem to predict the target variable. They are probabilistic, which means that they calculate the probability of each tag for a given text, and then output the tag with the highest one. The way they get these probabilities is by using Bayes’ Theorem, which describes the probability of a feature, based on prior knowledge of conditions that might be related to that feature.

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(X_train.toarray(),Y_train)
y_pred = nb.predict(X_test.toarray())
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.04      0.37      0.08        19
#            1       0.99      0.84      0.91       990
#
#     accuracy                           0.83      1009
#    macro avg       0.51      0.61      0.49      1009
# weighted avg       0.97      0.83      0.89      1009

# %% [markdown]
# ### Support Vector Machine
#
# The objective of the support vector machine algorithm is to find a hyperplane in an N-dimensional space(N — the number of features) that distinctly classifies the data points.
#
# To separate the two classes of data points, there are many possible hyperplanes that could be chosen. Hyperplanes are decision boundaries that help classify the data points. Our objective is to find a plane that has the maximum margin or the maximum distance between data points of both classes.

# %%
from sklearn import svm

sv = svm.SVC()
sv.fit(X_train.toarray(),Y_train)
y_pred = sv.predict(X_test.toarray())
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.04      0.11      0.05        19
#            1       0.98      0.94      0.96       990
#
#     accuracy                           0.93      1009
#    macro avg       0.51      0.52      0.51      1009
# weighted avg       0.96      0.93      0.95      1009

# %% [markdown]
# ### Xgboost
#
# XGBoost the Algorithm operates on decision trees, models that construct a graph that examines the input under various "if" statements (vertices in the graph). Whether the "if" condition is satisfied influences the next "if" condition and eventual prediction. XGBoost the Algorithm progressively adds more and more "if" conditions to the decision tree to build a stronger model.

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report

xgb = XGBClassifier()
xgb.fit(X_train,Y_train)
y_pred = xgb.predict(X_test)
print(classification_report(Y_test, y_pred))
# Out:
# [19:57:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#               precision    recall  f1-score   support
#
#            0       0.05      0.16      0.07        19
#            1       0.98      0.94      0.96       990
#
#     accuracy                           0.92      1009
#    macro avg       0.51      0.55      0.51      1009
# weighted avg       0.97      0.92      0.94      1009

# %% [markdown]
# ### Long Short-Term Memory (LSTM) – Keras Implementation
#
# The  Long  Short-Term  Memory  or  LSTM  network  is  a  recurrent  neural  net-work that is trained using Backpropagation Through Time and overcomes thevanishing gradient problem.  LSTMs differentiated by common RNNs by usingmemory blocks that are connected into layers.  A block has components thatmake it smarter than a classical neuron and a memory for recent sequences.Thiscapability of LSTMs has been used to great effect in complex natural languageprocessing problems such as neural machine translation.
#
# **Padding**
#
# The sequences have different lengths and Keras prefers inputs to be vectorized and all inputs to have the same length. We set the maximum size of each list to 1000. You can try a different size. The lists with size greater than 1000 will be truncated to 1000. For the lists that have length less than 1000, we will add 0 at the end of the list until it reaches the max length. This process is called padding.
#
# **Embedding**
#
# Embedding layer is one of the available layers in Keras. This is mainly used in Natural Language Processing related applications such as language modeling, but it can also be used with other tasks that involve neural networks. While dealing with NLP problems, we can use pre-trained word embeddings such as GloVe. Alternatively we can also train our own embeddings using Keras embedding layer. **Word embeddings can be thought of as an alternate to one-hot encoding along with dimensionality reduction.**
#
# Embedding layer enables us to convert each word into a fixed length vector of defined size. The resultant vector is a dense one with having real values instead of just 0’s and 1’s. The fixed length of word vectors helps us to represent words in a better way along with reduced dimensions.
#
# This way embedding layer works like a lookup table. The words are the keys in this table, while the dense word vectors are the values. To understand it better, let’s look at the implementation of Keras Embedding layer.

# %%
tf_idf_dict = list(vectorizer.vocabulary_.items())

max_val = 0
for i in range(0,len(tf_idf_dict)-1):
    current_val = tf_idf_dict[i][1]
    if current_val > max_val:
        max_val = current_val

vocab_size = max_val
print(vocab_size)
# Out:
# 2991

# %%
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, Dropout
from keras.preprocessing.sequence import pad_sequences

maxlen = 100

X_train = pad_sequences(X_train.toarray(), padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test.toarray(), padding='post', maxlen=maxlen)
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
from numpy import array
from numpy import asarray
from numpy import zeros

embeddings_dictionary = dict()
glove_file = open(r'glove.6B.100d.txt', encoding="utf8")

for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:], dtype='float32')
    embeddings_dictionary [word] = vector_dimensions
glove_file.close()

# %%
embedding_matrix = zeros((vocab_size, 100))
for word, index in vectorizer.vocabulary_.items():
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100, input_length = X_train.shape[1], weights=[embedding_matrix], trainable=False))
model.add(SpatialDropout1D(0.4))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss = 'binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 100)          299100
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 100, 100)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               117248
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 416,477
# Trainable params: 117,377
# Non-trainable params: 299,100
# _________________________________________________________________
# None

# %%
import tensorflow as tf

y_nn_train = tf.one_hot(Y_train, depth=1)
y_nn_test = tf.one_hot(Y_test, depth=1)

# %%
batch_size = 64
history = model.fit(X_train, Y_train, epochs = 5, batch_size=batch_size, validation_data=(X_test, y_nn_test))
# Out:
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <bound method LSTMCell._compute_carry_and_output of <keras.layers.recurrent.LSTMCell object at 0x000001CFBA075520>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: invalid syntax (tmpzy8yebc0.py, line 13)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method LSTMCell._compute_carry_and_output of <keras.layers.recurrent.LSTMCell object at 0x000001CFBA075520>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: invalid syntax (tmpzy8yebc0.py, line 13)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method Dense.call of <keras.layers.core.Dense object at 0x000001CFBA075640>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: invalid syntax (tmpnpeepx9p.py, line 48)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Dense.call of <keras.layers.core.Dense object at 0x000001CFBA075640>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: invalid syntax (tmpnpeepx9p.py, line 48)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 73/73 [==============================] - 63s 392ms/step - loss: 0.7017 - accuracy: 0.4981 - val_loss: 0.7125 - val_accuracy: 0.0188
# Epoch 2/5
# 73/73 [==============================] - 31s 430ms/step - loss: 0.6981 - accuracy: 0.4922 - val_loss: 0.6853 - val_accuracy: 0.9802
# Epoch 3/5
# 73/73 [==============================] - 31s 419ms/step - loss: 0.6956 - accuracy: 0.4909 - val_loss: 0.8169 - val_accuracy: 0.0188
# Epoch 4/5
# 73/73 [==============================] - 30s 410ms/step - loss: 0.6963 - accuracy: 0.5106 - val_loss: 0.6712 - val_accuracy: 0.9812
# Epoch 5/5
# 73/73 [==============================] - 31s 422ms/step - loss: 0.6944 - accuracy: 0.5146 - val_loss: 0.7114 - val_accuracy: 0.0188

# %%
y_pred = model.predict_classes(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        19
#            1       0.98      1.00      0.99       990
#
#     accuracy                           0.98      1009
#    macro avg       0.49      0.50      0.50      1009
# weighted avg       0.96      0.98      0.97      1009

# %% [markdown]
# ### AutoSklearnClassifier

# %%
from autosklearn.classification import AutoSklearnClassifier

X_train=X_train
y_train=Y_train
asc = AutoSklearnClassifier(time_left_for_this_task=10*60, n_jobs=8)
asc.fit(X_train,y_train)
print(classification_report(Y_test, y_pred))
# Out:
# /usr/local/lib/python3.7/dist-packages/tornado/httputil.py:107: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   class HTTPHeaders(collections.MutableMapping):
# /usr/local/lib/python3.7/dist-packages/autosklearn/automl.py:693: DeprecationWarning: dist() and linux_distribution() functions are deprecated in Python 3.5
#   self._logger.debug('  Distribution: %s', platform.linux_distribution())
# /usr/local/lib/python3.7/dist-packages/autosklearn/metalearning/metalearning/meta_base.py:68: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   runs = pd.Series([], name=name)
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7fed2d91ac20>
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7fed2b30e3d0>
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7fed2e2a88a0>
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7fed2cfa79f0>
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7fed2bda94b0>
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7fed2bc86670>
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7fed2e41ebb0>
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7fed2f694600>
#               precision    recall  f1-score   support
#
#            0       0.06      0.26      0.10        19
#            1       0.98      0.92      0.95       990
#
#     accuracy                           0.91      1009
#    macro avg       0.52      0.59      0.53      1009
# weighted avg       0.97      0.91      0.94      1009

# %% [markdown]
# # LSTM with Bidirectional Encoder Representations from Transformer BERT

# %%
from sklearn.model_selection import train_test_split

train, test= train_test_split(data, test_size = 0.3, random_state = 500)

# %%
from transformers import BertTokenizer, TFBertForSequenceClassification
from transformers import InputExample, InputFeatures

model = TFBertForSequenceClassification.from_pretrained("bert-base-uncased")
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def convert_data_to_examples(train, test, DATA_COLUMN, LABEL_COLUMN): 
  train_InputExamples = train.apply(lambda x: InputExample(guid=None, # Globally unique ID for bookkeeping, unused in this case
                                                          text_a = x[DATA_COLUMN], 
                                                          text_b = None,
                                                          label = x[LABEL_COLUMN]), axis = 1)

  validation_InputExamples = test.apply(lambda x: InputExample(guid=None, # Globally unique ID for bookkeeping, unused in this case
                                                          text_a = x[DATA_COLUMN], 
                                                          text_b = None,
                                                          label = x[LABEL_COLUMN]), axis = 1)
  
  return train_InputExamples, validation_InputExamples

  train_InputExamples, validation_InputExamples = convert_data_to_examples(train, 
                                                                           test, 
                                                                           'Reviews', 
                                                                           'Rating')
  
def convert_examples_to_tf_dataset(examples, tokenizer, max_length=128):
    features = [] # -> will hold InputFeatures to be converted later

    for e in examples:
        # Documentation is really strong for this method, so please take a look at it
        input_dict = tokenizer.encode_plus(
            e.text_a,
            add_special_tokens=True,
            max_length=max_length, # truncates if len(s) > max_length
            return_token_type_ids=True,
            return_attention_mask=True,
            pad_to_max_length=True, # pads to the right by default # CHECK THIS for pad_to_max_length
            truncation=True
        )

        input_ids, token_type_ids, attention_mask = (input_dict["input_ids"],
            input_dict["token_type_ids"], input_dict['attention_mask'])

        features.append(
            InputFeatures(
                input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids, label=e.label
            )
        )

    def gen():
        for f in features:
            yield (
                {
                    "input_ids": f.input_ids,
                    "attention_mask": f.attention_mask,
                    "token_type_ids": f.token_type_ids,
                },
                f.label,
            )

    return tf.data.Dataset.from_generator(
        gen,
        ({"input_ids": tf.int32, "attention_mask": tf.int32, "token_type_ids": tf.int32}, tf.int64),
        (
            {
                "input_ids": tf.TensorShape([None]),
                "attention_mask": tf.TensorShape([None]),
                "token_type_ids": tf.TensorShape([None]),
            },
            tf.TensorShape([]),
        ),
    )


DATA_COLUMN = 'Review'
LABEL_COLUMN = 'Rating'

# %%
import tensorflow as tf

train_InputExamples, validation_InputExamples = convert_data_to_examples(train, test, DATA_COLUMN, LABEL_COLUMN)

train_data = convert_examples_to_tf_dataset(list(train_InputExamples), tokenizer)
train_data = train_data.shuffle(100).batch(32).repeat(2)

validation_data = convert_examples_to_tf_dataset(list(validation_InputExamples), tokenizer)
validation_data = validation_data.batch(32)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5, epsilon=1e-08, clipnorm=1.0), 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy('accuracy')])

model.fit(train_data, epochs=2, steps_per_epoch=5)
# Out:
# Epoch 1/2
# WARNING:tensorflow:From C:\Users\panag\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 5/5 [==============================] - 232s 37s/step - loss: 0.3769 - accuracy: 0.9812
# Epoch 2/2
# 5/5 [==============================] - 188s 38s/step - loss: 0.1878 - accuracy: 0.9812

# %%
from sklearn.metrics import classification_report

tf_batch = tokenizer(test['Review'].tolist(), max_length=128, padding=True, truncation=True, return_tensors='tf')
tf_outputs = model(tf_batch)

tf_predictions = tf.nn.softmax(tf_outputs[0], axis=-1)
labels = [0,1]
label = tf.argmax(tf_predictions, axis=1)
label = label.numpy()
print(classification_report(test['Rating'], label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        21
#            1       0.98      1.00      0.99       988
#
#     accuracy                           0.98      1009
#    macro avg       0.49      0.50      0.49      1009
# weighted avg       0.96      0.98      0.97      1009
